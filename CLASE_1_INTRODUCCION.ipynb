# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabrielore1/DiplomadoGADIA/blob/main/CLASE_1_INTRODUCCION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INTRODUCCIÓN A PYTHON**
#
# DIPLOMADO EN GOBIERNO Y ANALITICA DE DATOS
#
# FUNDACION UNIVERSITARIA CAFAM
#
# DOCENTE: NICOLAS MOJICA GOMEZ
#
# ESTUDIANTE: GABRIEL ORELLANO
#
#
#
# ---

# %% [markdown]
# ## 1.Comentarios en los códigos
#
# para documentar códigos en PYTHON existen diferentes formas de crear comentarios, esto nos permite comentar nuestras secuencias de comando para su analisis o posterior Modificación

# %%
# Este comentario es de una sola linea
#Python es un programa sencible a las mayusculas y minusculas
print("Hola mundo")
# Out:
# Hola mundo

# %%
'''
Este comentario es de multiples lineas
puede extenderse  en varias lineas
'''
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# ## 2. Variables
# Una variable es un elemento de un lenguaje  de programación  que tiene asignado un valor determinado

# %%
## para crear una variable en Python se le debe proporcionar un nombre y se le debe asignar un valor usando un (=)
var="Hola mundo"
print(var)
# Out:
# Hola mundo

# %%
## Las variables pueden cambiar duranto o a lo largo del programa en Python
var="adios mundo"
print("adios mundo")
# Out:
# adios mundo

# %%
## La variables en Python son sensibles a las mayusculas y minusculas

# %% [markdown]
# ##3. TIPOS DE DATOS

# %%
#Tipos de datos numericos
enteros=42
# En la  mayor  parte  de lenguaje de programacion los enteros son represenrados con "int"

# %%
#tipo de datos flotante
Flotante=3 .14151
# Out:
#   File "<ipython-input-2-f49c104ea2b3>", line 2
#     Flotante=3 .14151
#                ^
# SyntaxError: invalid syntax

# %%
# conversion  de los tipos de datos
#convertir  un flotante en un numero entero
entrero= int(3.14)
print(entero)

# %%
#convertir entero a flotante
flotante= float(5)
print(flotante)
# Out:
# 5.0

# %% [markdown]
# ## 4. Operaciones  artitmetca
# Las operaciones de matematicas se utilizan PARA Rrealizar operaciones comunes como la adiccion, sustracion y multiplicacion

# %%
# suma
a=10
b=5
print(a+b)
# Out:
# 15

# %%
#Reta
c=a-b
print(c)
# Out:
# 5

# %%
# Multiplicacion
d=a*b
print(d)
# Out:
# 50

# %%
#dicvicion
e=a/b
print(e)
# Out:
# 2.0

# %%
#Divicion entrera
print(a//b)
# Out:
# 2

# %%
# Modulo risiduo de una operacion
print(a%b)
# Out:
# 0

# %%
# Exponenciacion
print(a**b)
# Out:
# 100000

# %%
# Asignacion compuesta
a+=b
print(a)
# Out:
# 15

# %%
a-b
print(a)
# Out:
# 10

# %%
# redondeo
var4= 3.1410
print(round(var4,2))
# Out:
# 3.14
